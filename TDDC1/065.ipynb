# %%
import numpy as np
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def func1 (x):
    return 5 * x + 3

# %%
x = np.linspace(-10,10, 100)

# %%
plt.figure(figsize = (20,6))
plt.plot(x, func1(x))
plt.grid(True)

# %%
def func_sin (x):
    return np.sin(x)

# %%
def func_cos (x):
    return np.cos(x)

# %%
plt.figure(figsize = (20,6))
plt.plot(x, func_sin(x))
plt.plot(x, func_cos(x))
plt.grid(True)

# %%
a = np.random.uniform(0.0, 1.0, 1000)
b = np.random.uniform(0.0, 1.0, 1000)

# %%
plt.figure(figsize=(20,6))
# 2行1列の1つ目
plt.subplot(2,1,1)
plt.hist(a)
# 2行1列の2つ目
plt.subplot(2,1,2)
plt.hist(b)

plt.grid(True)

# %%
import math

# %%
x = np.random.uniform(0.0, 1.0, 10000)
y = np.random.uniform(0.0, 1.0, 10000)

# %%
inside_x = []
inside_y = []

outside_x = []
outside_y = []

count_inside = 0

for count in range(0, 10000):
    d = math.hypot(x[count], y[count])
    if (d < 1):
        count_inside += 1
        inside_x.append(x[count])
        inside_y.append(y[count])
    else :
        outside_x.append(x[count])
        outside_y.append(y[count])

print("円の中の数:", count_inside)
# Out:
# 円の中の数: 7821

# %%
plt.figure(figsize = (5,5))

circle_x = np.arange(0, 1, 0.001)
circle_y = np.sqrt(1-circle_x * circle_x)
plt.plot(circle_x, circle_y)

plt.scatter(inside_x, inside_y, color = "r")
plt.scatter(outside_x, outside_y, color = "b")
plt.grid(True)

# %%
4 * count_inside / 10000
# Out:
# 3.1284
