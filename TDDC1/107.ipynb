# %%
import requests
import zipfile
from io import StringIO
import io

# %%
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
student_data_math = pd.read_csv('chap3/student-mat.csv', sep=';')

# %%
#密度関数
student_data_math.absences.plot(kind = 'kde', style = 'k--')
student_data_math.absences.hist(density=True)
plt.grid(True)

# %%
N = 10000
nomal_sample_data = [np.random.normal(0,1,100).mean() for _ in range(N)]

plt.hist(nomal_sample_data)
plt.grid(True)

# %%
N = 10000
nomal_sample_data = [np.random.lognormal(0,1,100).mean() for _ in range(N)]

plt.hist(nomal_sample_data)
plt.grid(True)

# %%
#密度関数
student_data_math.G1.plot(kind = 'kde', style = 'k--')
student_data_math.G1.hist(density=True)
plt.grid(True)
